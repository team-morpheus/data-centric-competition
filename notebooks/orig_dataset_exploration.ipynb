# %% [markdown]
# # Original Dataset Exploration

# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("../") # go to root dir

# %%
from common.visualizations.photo_slider import multi_channel_tile_slider
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
multi_channel_tile_slider(None)
# Out:
#   <div class="bk-root" id="92075429-a354-42ff-9b6e-3cf98ae035fe" data-root-id="1114"></div>

# %%
a = 5123
b = 2
print(a)
print(b)

# %%
a = 322
print(a)

# %%
print("hello world")
