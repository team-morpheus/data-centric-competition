# %% [markdown]
# # Original Dataset Exploration`

# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("../") # go to root dir
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from common.visualizations.photo_slider import multi_channel_tile_slider
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
multi_channel_tile_slider(r"C:\Users\yonil\PycharmProjects\data-centric-competition\data\orig\val\i")
# Out:
#   <div class="bk-root" id="cf20a3bb-520b-4db9-8d62-925072851b04" data-root-id="1389"></div>

# %%
multi_channel_tile_slider(r"C:\Users\yonil\PycharmProjects\data-centric-competition\data\orig\train\i", 200)
# Out:
#   <div class="bk-root" id="dc4b4dbd-182a-43ed-8ba6-7608a49adf08" data-root-id="1839"></div>

# %%
a = 5123
b = 2
print(a)
print(b)

# %%
a = 322
print(a)

# %%
print("hello world")
